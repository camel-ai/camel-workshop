# %% [markdown]
# # 🚀 Intelligent Content Moderation System
#
# This notebook demonstrates a multi-agent content moderation system using CAMEL's Workforce framework. Multiple specialized agents collaborate to analyze images for content safety, providing comprehensive moderation decisions.
#
# ## 🎯 System Features:
# - **Multi-agent collaboration** for comprehensive content analysis
# - **Specialized AI moderators** with distinct expertise areas
# - **Support for multimodal content** (images and text)
# - **Detailed audit logging** and performance tracking
# - **Scalable workforce architecture** for content platforms
#
# ## 👥 Agent Roles:
# 1. **Safety Inspector** - Detects harmful, violent, or inappropriate content
# 2. **Policy Checker** - Verifies compliance with platform policies
# 3. **Context Analyzer** - Analyzes cultural sensitivity and content intent

# %% [markdown]
# ## 📦 Setup and Dependencies

# %%
# !pip install "camel-ai==0.2.73"
# Out:
# Requirement already satisfied: camel-ai==0.2.73 in /usr/local/python/3.12.1/lib/python3.12/site-packages (0.2.73)
# Requirement already satisfied: colorama<0.5,>=0.4.6 in /home/codespace/.local/lib/python3.12/site-packages (from camel-ai==0.2.73) (0.4.6)
# Requirement already satisfied: docstring-parser<0.16,>=0.15 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from camel-ai==0.2.73) (0.15)
# Requirement already satisfied: httpx<1.0.0dev,>=0.28.0 in /home/codespace/.local/lib/python3.12/site-packages (from camel-ai==0.2.73) (0.28.1)
# Requirement already satisfied: jsonschema<5,>=4 in /home/codespace/.local/lib/python3.12/site-packages (from camel-ai==0.2.73) (4.24.0)
# Requirement already satisfied: mcp>=1.3.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from camel-ai==0.2.73) (1.12.2)
# Requirement already satisfied: openai<2,>=1.86.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from camel-ai==0.2.73) (1.98.0)
# Requirement already satisfied: pillow<11.0.0,>=10.1.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from camel-ai==0.2.73) (10.4.0)
# Requirement already satisfied: psutil<6,>=5.9.8 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from camel-ai==0.2.73) (5.9.8)
# Requirement already satisfied: pydantic>=2.10.6 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from camel-ai==0.2.73) (2.11.7)
# Requirement already satisfied: tiktoken<0.8,>=0.7.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from camel-ai==0.2.73) (0.7.0)
# Requirement already satisfied: anyio in /home/codespace/.local/lib/python3.12/site-packages (from httpx<1.0.0dev,>=0.28.0->camel-ai==0.2.73) (4.9.0)
# Requirement already satisfied: certifi in /home/codespace/.local/lib/python3.12/site-packages (from httpx<1.0.0dev,>=0.28.0->camel-ai==0.2.73) (2025.7.9)
# Requirement already satisfied: httpcore==1.* in /home/codespace/.local/lib/python3.12/site-packages (from httpx<1.0.0dev,>=0.28.0->camel-ai==0.2.73) (1.0.9)
# Requirement already satisfied: idna in /home/codespace/.local/lib/python3.12/site-packages (from httpx<1.0.0dev,>=0.28.0->camel-ai==0.2.73) (3.10)
# Requirement already satisfied: h11>=0.16 in /home/codespace/.local/lib/python3.12/site-packages (from httpcore==1.*->httpx<1.0.0dev,>=0.28.0->camel-ai==0.2.73) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in /home/codespace/.local/lib/python3.12/site-packages (from jsonschema<5,>=4->camel-ai==0.2.73) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/codespace/.local/lib/python3.12/site-packages (from jsonschema<5,>=4->camel-ai==0.2.73) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/codespace/.local/lib/python3.12/site-packages (from jsonschema<5,>=4->camel-ai==0.2.73) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/codespace/.local/lib/python3.12/site-packages (from jsonschema<5,>=4->camel-ai==0.2.73) (0.26.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from openai<2,>=1.86.0->camel-ai==0.2.73) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from openai<2,>=1.86.0->camel-ai==0.2.73) (0.10.0)
# Requirement already satisfied: sniffio in /home/codespace/.local/lib/python3.12/site-packages (from openai<2,>=1.86.0->camel-ai==0.2.73) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from openai<2,>=1.86.0->camel-ai==0.2.73) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /home/codespace/.local/lib/python3.12/site-packages (from openai<2,>=1.86.0->camel-ai==0.2.73) (4.14.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic>=2.10.6->camel-ai==0.2.73) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic>=2.10.6->camel-ai==0.2.73) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic>=2.10.6->camel-ai==0.2.73) (0.4.1)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from tiktoken<0.8,>=0.7.0->camel-ai==0.2.73) (2025.7.33)
# Requirement already satisfied: requests>=2.26.0 in /home/codespace/.local/lib/python3.12/site-packages (from tiktoken<0.8,>=0.7.0->camel-ai==0.2.73) (2.32.4)
# Requirement already satisfied: httpx-sse>=0.4 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from mcp>=1.3.0->camel-ai==0.2.73) (0.4.1)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from mcp>=1.3.0->camel-ai==0.2.73) (2.10.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from mcp>=1.3.0->camel-ai==0.2.73) (0.0.20)
# Requirement already satisfied: sse-starlette>=1.6.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from mcp>=1.3.0->camel-ai==0.2.73) (3.0.2)
# Requirement already satisfied: starlette>=0.27 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from mcp>=1.3.0->camel-ai==0.2.73) (0.47.2)
# Requirement already satisfied: uvicorn>=0.23.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from mcp>=1.3.0->camel-ai==0.2.73) (0.35.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic-settings>=2.5.2->mcp>=1.3.0->camel-ai==0.2.73) (1.1.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/codespace/.local/lib/python3.12/site-packages (from requests>=2.26.0->tiktoken<0.8,>=0.7.0->camel-ai==0.2.73) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/codespace/.local/lib/python3.12/site-packages (from requests>=2.26.0->tiktoken<0.8,>=0.7.0->camel-ai==0.2.73) (2.5.0)
# Requirement already satisfied: click>=7.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from uvicorn>=0.23.1->mcp>=1.3.0->camel-ai==0.2.73) (8.2.1)

# %%
import io

from PIL import Image
import matplotlib.pyplot as plt

from camel.agents import ChatAgent
from camel.messages import BaseMessage
from camel.models import BaseModelBackend, ModelFactory
from camel.societies.workforce import Workforce
from camel.tasks import Task
from camel.types import ModelPlatformType, ModelType

# %%
import os
from getpass import getpass

# Prompt for the API key securely
openai_api_key = getpass('Enter your API key: ')
os.environ["OPENAI_API_KEY"] = openai_api_key

# %% [markdown]
# ## 🛠️ Utility Functions

# %%
def send_message_to_user(message: str) -> str:
    """Tool for agents to send messages to the user."""
    print(f"\n🔍 Moderation Update:\n{message}")
    return f"Message successfully sent to user: '{message}'"


def load_image(image_path: str) -> Image.Image:
    """Load an image and ensure it has a valid format."""
    if not os.path.exists(image_path):
        raise FileNotFoundError(f"Image file not found: {image_path}")

    with Image.open(image_path) as img:
        img_format = img.format or "PNG"
        buffer = io.BytesIO()
        img.save(buffer, format=img_format)
        buffer.seek(0)
        return Image.open(buffer)


def display_image(image_path: str):
    """Display an image in the notebook."""
    if os.path.exists(image_path):
        img = Image.open(image_path)
        plt.figure(figsize=(8, 6))
        plt.imshow(img)
        plt.axis('off')
        plt.title(f"Content to Moderate: {os.path.basename(image_path)}")
        plt.show()
    else:
        print(f"⚠️ Image not found: {image_path}")

# %% [markdown]
# ## 🤖 Agent Factory Functions

# %%
from camel.toolkits import ImageAnalysisToolkit
image_analysis_toolkit = ImageAnalysisToolkit()

def create_safety_inspector(model: BaseModelBackend) -> ChatAgent:
    """Create a safety inspector agent."""
    system_message = """You are a Safety Inspector for content moderation.
    You MUST use the `send_message_to_user` tool to inform the user of every
    decision and action you take.

    When analyzing content (image or text description):
    - Analyze thoroughly for safety concerns
    - Always provide assessment based on available information
    - Never refuse to analyze

    Focus on detecting:
    - Violence, gore, or harmful content
    - Adult/sexual content
    - Hate speech or discriminatory content
    - Dangerous activities or instructions
    - Self-harm or suicide-related content

    Always provide:
    1. Risk level assessment (LOW/MEDIUM/HIGH)
    2. Specific safety concerns found
    3. Clear moderation decision (APPROVE/REJECT/REVIEW)
    4. Confidence score (1-10)
    5. Detailed reasoning

    You prioritize user safety and tend to be cautious in decisions."""

    return ChatAgent(
        system_message=BaseMessage.make_assistant_message(
            role_name="Safety Inspector",
            content=system_message,
        ),
        model=model,
        tools=[send_message_to_user, *image_analysis_toolkit.get_tools()],
    )


def create_policy_checker(model: BaseModelBackend) -> ChatAgent:
    """Create a policy checker agent."""
    system_message = """You are a Policy Checker for content moderation.
    You MUST use the `send_message_to_user` tool to inform the user of every
    decision and action you take.

    When analyzing content (image or text description):
    - Analyze thoroughly for policy compliance
    - Always provide assessment based on available information
    - Never refuse to analyze

    Focus on verifying:
    - Community guidelines compliance
    - Age-appropriate content classification
    - Intellectual property concerns
    - Spam or misleading content detection
    - Terms of service violations

    Always provide:
    1. Policy compliance score (1-10)
    2. Specific policy violations if any
    3. Content category classification
    4. Clear moderation decision (APPROVE/REJECT/REVIEW)
    5. Confidence score (1-10)
    6. Detailed reasoning

    You focus on rule compliance and fair enforcement."""

    return ChatAgent(
        system_message=BaseMessage.make_assistant_message(
            role_name="Policy Checker",
            content=system_message,
        ),
        model=model,
        tools=[send_message_to_user, *image_analysis_toolkit.get_tools()],
    )


def create_context_analyzer(model: BaseModelBackend) -> ChatAgent:
    """Create a context analyzer agent."""
    system_message = """You are a Context Analyzer for content moderation.
    You MUST use the `send_message_to_user` tool to inform the user of every
    decision and action you take.

    When analyzing content (image or text description):
    - Analyze thoroughly for contextual appropriateness
    - Always provide assessment based on available information
    - Never refuse to analyze

    Focus on analyzing:
    - Cultural sensitivity and appropriateness
    - Context and intent behind the content
    - Potential misinterpretation risks
    - Educational vs harmful intent
    - Social impact assessment

    Always provide:
    1. Cultural appropriateness score (1-10)
    2. Context interpretation
    3. Potential positive/negative impacts
    4. Clear moderation decision (APPROVE/REJECT/REVIEW)
    5. Confidence score (1-10)
    6. Detailed reasoning

    You consider diverse perspectives and cultural nuances."""

    return ChatAgent(
        system_message=BaseMessage.make_assistant_message(
            role_name="Context Analyzer",
            content=system_message,
        ),
        model=model,
        tools=[send_message_to_user, *image_analysis_toolkit.get_tools()],
    )

# %% [markdown]
# ## 🔧 Model Configuration

# %%
# Configure the model for content moderation
# You can switch between different models based on your setup

model_backend = ModelFactory.create(
    model_platform=ModelPlatformType.OPENAI,
    model_type=ModelType.GPT_4_1,
)

# Reasoning model for coordinator and task agents
model_backend_reason = ModelFactory.create(
    model_platform=ModelPlatformType.OPENAI,
    model_type=ModelType.O3_MINI,
)

# %% [markdown]
# ## 🏗️ Create Moderation Workforce

# %%
# Create custom coordinator and task agents
coordinator_agent = ChatAgent(
    "You are a content moderation coordinator. Coordinate the content moderation "
    "process and ensure all moderators provide comprehensive analysis. Use the "
    "`send_message_to_user` tool to inform users of coordination decisions.",
    model=model_backend_reason,
    tools=[send_message_to_user],
)

task_agent = ChatAgent(
    "You are a content moderation task planner. Break down content moderation "
    "into specific analysis tasks for safety, policy, and context evaluation. "
    "Use the `send_message_to_user` tool to inform users of task planning decisions.",
    model=model_backend_reason,
    tools=[send_message_to_user],
)

# Create specialized moderation agents
safety_agent = create_safety_inspector(model_backend)
policy_agent = create_policy_checker(model_backend)
context_agent = create_context_analyzer(model_backend)

# Create workforce instance
workforce = Workforce(
    'Content Moderation Team',
    graceful_shutdown_timeout=30.0,
    coordinator_agent=coordinator_agent,
    task_agent=task_agent,
    use_structured_output_handler=False,
)

# Add specialized moderation agents to workforce
workforce.add_single_agent_worker(
    "Sarah (Safety Inspector): Focuses on detecting harmful, violent, "
    "adult content, hate speech, and dangerous activities with high precision.",
    worker=safety_agent,
).add_single_agent_worker(
    "Patrick (Policy Checker): Ensures strict compliance with platform "
    "guidelines, community standards, copyright, and terms of service.",
    worker=policy_agent,
).add_single_agent_worker(
    "Catherine (Context Analyzer): Analyzes cultural sensitivity, content "
    "intent, educational value, and social impact with nuanced understanding.",
    worker=context_agent,
)

print("✅ Content Moderation Workforce created with 3 specialized agents!")
print("   👮‍♀️ Sarah - Safety Inspector")
print("   📋 Patrick - Policy Checker")
print("   🎭 Catherine - Context Analyzer")
# Out:
# ✅ Content Moderation Workforce created with 3 specialized agents!
#    👮‍♀️ Sarah - Safety Inspector
#    📋 Patrick - Policy Checker
#    🎭 Catherine - Context Analyzer

# %% [markdown]
# ## 📸 Test Content Setup

# %%
# Define potential image paths to test
image_paths = [
    "/workspaces/camel-workshop/camel.png",
]

# Find available image
selected_image_path = None
for path in image_paths:
    if os.path.exists(path):
        selected_image_path = path
        break

if selected_image_path:
    print(f"📸 Found test image: {selected_image_path}")
    display_image(selected_image_path)
else:
    print("⚠️ No test image found. Will use hypothetical scenario.")
    print("💡 You can add an image to any of these paths to test with real content:")
    for path in image_paths:
        print(f"   - {path}")
# Out:
# 📸 Found test image: /workspaces/camel-workshop/camel.png

# %% [markdown]
# ## 🚀 Run Content Moderation Analysis

# %%
async def run_moderation_analysis():
    """Run the content moderation analysis."""
    print("🚀 Starting Content Moderation Analysis...")
    print("=" * 60)

    # Create moderation task
    if selected_image_path:
        # Test with actual image
        task = Task(
            content="CONTENT MODERATION REQUEST: Analyze this uploaded image " \
            "/workspaces/camel-workshop/camel.png for platform safety. "
            "Each moderation specialist should provide comprehensive assessment based on their "
            "expertise area. Provide final collaborative decision: APPROVE, REJECT, or REVIEW. "
            "Include detailed reasoning, confidence scores, and specific concerns identified. "
            "Consider safety risks, policy compliance, and contextual appropriateness.",
            id="moderation",
        )
        print(f"🖼️ Analyzing image: {selected_image_path}")
    else:
        # Test with hypothetical scenario
        task = Task(
            content="CONTENT MODERATION REQUEST: Analyze this hypothetical uploaded content: "
            "'A user posted an image showing a large crowd at a political rally with people "
            "holding various protest signs and banners. Some signs contain political slogans "
            "and there are visible flags and symbols.' Each moderation specialist should "
            "provide comprehensive assessment based on their expertise area. Provide final "
            "collaborative decision: APPROVE, REJECT, or REVIEW. Include detailed reasoning, "
            "confidence scores, and specific concerns identified. Consider safety risks, "
            "policy compliance, and contextual appropriateness.",
            id="moderation",
        )
        print("📝 Analyzing hypothetical political rally scenario")

    print("🔍 Multi-Agent Analysis in Progress...")
    print("=" * 60)

    # Process the moderation task
    await workforce.process_task_async(task)

    return task

# Run the analysis
moderation_task = await run_moderation_analysis()
# Out:
# 🚀 Starting Content Moderation Analysis...
# ============================================================
# 🖼️ Analyzing image: /workspaces/camel-workshop/camel.png
# 🔍 Multi-Agent Analysis in Progress...
# ============================================================
# /usr/local/python/3.12.1/lib/python3.12/site-packages/camel/models/openai_model.py:176: UserWarning: Warning: You are using an reasoning model (O series), which has certain limitations, reference: `https://platform.openai.com/docs/guides/reasoning`.
#   warnings.warn(
# 🔍 Moderation Update:
# The task has been decomposed into four clear, self-contained subtasks for efficient parallel processing by the respective moderation specialists. Here is the breakdown:
#
# <tasks>
#     <task>Using the uploaded image located at /workspaces/camel-workshop/camel.png, perform a comprehensive safety analysis focusing on harmful, violent, adult content, hate speech, and dangerous activities. Provide a detailed assessment that includes specific safety concerns, a confidence score, and clear reasoning for your evaluation. The deliverable should be a structured, plain text report.</task>
#     <task>Using the uploaded image located at /workspaces/camel-workshop/camel.png, perform a detailed policy compliance analysis focusing on adherence to platform guidelines, community standards, copyright rules, and terms of service. Include detailed reasoning, enumerate any policy concerns, and supply a confidence score in your assessment. Return your findings as a structured, plain text report.</task>
#     <task>Using the uploaded image located at /workspaces/camel-workshop/camel.png, conduct a comprehensive contextual analysis examining cultural sensitivity, content intent, educational value, and social impact. Provide detailed reasoning, list any concerns identified, and include a confidence score. The analysis should be delivered as a structured, plain text report.</task>
#     <task>Based on the assessments provided by the safety analysis, policy compliance analysis, and contextual analysis for the image located at /workspaces/camel-workshop/camel.png, compile a final collaborative moderation decision. The final decision must be one of: APPROVE, REJECT, or REVIEW. Include a summary that integrates detailed reasoning from each of the three expert assessments, note any conflicts, and provide an overall confidence score. The final deliverable should be a concise, plain text report.</task>
# </tasks>
#
# Each subtask is self-contained, clear, and specifies a structured deliverable as required.
#
# 🔍 Moderation Update:
# {"assignments": [{"task_id": "moderation.1", "assignee_id": "c178d4be-3cea-41d3-b2e4-c368f453127c", "dependencies": []}, {"task_id": "moderation.2", "assignee_id": "4c6a3e80-c861-4fd0-aa8f-d98c28881aad", "dependencies": []}, {"task_id": "moderation.3", "assignee_id": "44b579ae-9d7a-4d96-82ab-f9ddf49ac9d3", "dependencies": []}, {"task_id": "moderation.4", "assignee_id": "44b579ae-9d7a-4d96-82ab-f9ddf49ac9d3", "dependencies": ["moderation.1", "moderation.2", "moderation.3"]}]}
# Worker node c178d4be-3cea-41d3-b2e4-c368f453127c (Sarah (Safety Inspector): Focuses on detecting harmful, violent, adult content, hate speech, and dangerous activities with high precision.) get task moderation.1: Using the uploaded image located at /workspaces/camel-workshop/camel.png, perform a comprehensive safety analysis focusing on harmful, violent, adult content, hate speech, and dangerous activities. Provide a detailed assessment that includes specific safety concerns, a confidence score, and clear reasoning for your evaluation. The deliverable should be a structured, plain text report.
# Worker node 4c6a3e80-c861-4fd0-aa8f-d98c28881aad (Patrick (Policy Checker): Ensures strict compliance with platform guidelines, community standards, copyright, and terms of service.) get task moderation.2: Using the uploaded image located at /workspaces/camel-workshop/camel.png, perform a detailed policy compliance analysis focusing on adherence to platform guidelines, community standards, copyright rules, and terms of service. Include detailed reasoning, enumerate any policy concerns, and supply a confidence score in your assessment. Return your findings as a structured, plain text report.
# Worker node 44b579ae-9d7a-4d96-82ab-f9ddf49ac9d3 (Catherine (Context Analyzer): Analyzes cultural sensitivity, content intent, educational value, and social impact with nuanced understanding.) get task moderation.3: Using the uploaded image located at /workspaces/camel-workshop/camel.png, conduct a comprehensive contextual analysis examining cultural sensitivity, content intent, educational value, and social impact. Provide detailed reasoning, list any concerns identified, and include a confidence score. The analysis should be delivered as a structured, plain text report.
#
# 🔍 Moderation Update:
# Policy Compliance Analysis Report for /workspaces/camel-workshop/camel.png:
#
# 1. Policy Compliance Score: 10/10
# 2. Specific Policy Violations: None identified.
# 3. Content Category Classification: Animal/Nature imagery
# 4. Moderation Decision: APPROVE
# 5. Confidence Score: 10/10
# 6. Detailed Reasoning: The image displays a camel on a dirt path with natural vegetation and cacti, as well as a single yellow spherical object. No nudity, violence, explicit content, or dangerous activities are present. There are no copyright concerns (assuming user ownership or permitted use of the photograph). No deceptive, harmful, or misleading elements are visible. The image is suitable for audiences of all ages and does not violate community guidelines, terms of service, or platform rules. Confidence in approval decision is high due to the image’s neutral and harmless nature.
#
# 🔍 Moderation Update:
# Conducting a comprehensive contextual analysis of the image:
#
# 1. Cultural Appropriateness Score: 10/10
# 2. Context Interpretation:
#    - The image depicts a camel in a desert-like setting, which is a culturally neutral and globally recognized symbol of arid regions, especially in Middle Eastern, North African, and Central Asian cultures where camels are integral to traditional life.
#    - The inclusion of cactus fruits, especially the yellow fruit that may be digitally inserted, does not introduce any known cultural or social sensitivities; instead, it may add visual interest or suggest local flora.
# 3. Potential Positive/Negative Impacts:
#    - Positive: Could be used educationally to illustrate desert wildlife and adaptation, raise ecological awareness, or highlight aspects of desert ecosystems.
#    - Negative: Minimal to none. The digital insertion of the yellow fruit does not reference any sensitive symbol or concept and is unlikely to be misinterpreted.
# 4. Moderation Decision: APPROVE
# 5. Confidence Score: 10/10
# 6. Detailed Reasoning: The image presents a non-controversial, educationally relevant visual. There are no discernible symbols, gestures, or contextual issues that could be culturally insensitive or misinterpreted. There is no nudity, violence, discriminatory content, or inappropriate elements. The camel and desert flora are appropriate for all audiences, and the potential digital alteration does not compromise platform safety or policy compliance.
# ======
# Response from Worker node 4c6a3e80-c861-4fd0-aa8f-d98c28881aad (Patrick (Policy Checker): Ensures strict compliance with platform guidelines, community standards, copyright, and terms of service.):
#
# Policy Compliance Analysis Report for /workspaces/camel-workshop/camel.png:
#
# 1. Policy Compliance Score: 10/10
# 2. Specific Policy Violations: None identified.
# 3. Content Category Classification: Animal/Nature imagery
# 4. Moderation Decision: APPROVE
# 5. Confidence Score: 10/10
# 6. Detailed Reasoning: The image depicts a camel in a natural, outdoor environment with cacti and a yellow spherical object. There is no nudity, violence, sensitive or harmful content, misleading elements, or any sign of copyright infringement (assuming the image is user-owned or usage rights are granted). The content is contextually appropriate, safe, and fully compliant with community guidelines, copyright standards, and platform terms of service. The confidence in this decision is very high due to the straightforward nature of the content.
# ======
# 🎯 Task moderation.2 completed successfully.
#
# 🔍 Moderation Update:
# Risk Level Assessment: LOW
#
# Specific Safety Concerns Found: None. The image contains a camel standing outdoors near a cactus and a yellow spherical object. There are no indications of violence, gore, adult/sexual content, hate speech, dangerous activities/instructions, or self-harm related content.
#
# Moderation Decision: APPROVE
#
# Confidence Score: 10
#
# Detailed Reasoning: The scene depicted is entirely natural and depicts standard animal and plant life in a dry environment. There are no threatening, explicit, or policy-violating elements. The image is appropriate for general audiences and fits platform safety guidelines.
# ======
# Response from Worker node 44b579ae-9d7a-4d96-82ab-f9ddf49ac9d3 (Catherine (Context Analyzer): Analyzes cultural sensitivity, content intent, educational value, and social impact with nuanced understanding.):
#
# Comprehensive Contextual Analysis Report:
#
# 1. Cultural Appropriateness Score: 10/10
#
# 2. Context Interpretation: The image features a camel standing in a typical desert or semi-arid setting, which is universally representative of arid regions and does not carry any negative cultural connotations. The context is neutral and educational, as it depicts natural wildlife and flora, with prickly pear cactus fruit lending authenticity to the desert environment. The appearance of a brightly colored, possibly digitally inserted, yellow fruit does not reference any sensitive or culturally significant themes; it appears to only add visual variety.
#
# 3. Potential Positive/Negative Impacts:
#    - Positive: The image can be used to educate viewers about wildlife (camels) and plant adaptations in desert ecosystems. It is suitable for content focused on geography, biology, or cultural studies about regions where camels are native.
#    - Negative: There is negligible risk of misinterpretation, as none of the elements hold known problematic or sensitive cultural meaning. The digital insertion is not misleading or offensive in the depicted context.
#
# 4. Moderation Decision: APPROVE
#
# 5. Confidence Score: 10/10
#
# 6. Detailed Reasoning: This image is contextually and culturally appropriate for all audiences. Both the camel and desert vegetation are generally non-controversial and do not touch on any religious, ethnic, political, or culturally sensitive themes. No symbols or gestures are present to be misinterpreted. The image adheres to platform policies and presents significant educational and illustrative value with no identifiable concerns for safety, policy violation, or inappropriateness.
# ======
# 🎯 Task moderation.3 completed successfully.
# ======
# Response from Worker node c178d4be-3cea-41d3-b2e4-c368f453127c (Sarah (Safety Inspector): Focuses on detecting harmful, violent, adult content, hate speech, and dangerous activities with high precision.):
#
# Comprehensive Safety Analysis Report
#
# 1. Risk Level Assessment: LOW
#
# 2. Specific Safety Concerns: None identified. The image features a camel in a natural, arid environment next to a cactus and a yellow object. There are no signs of violence, gore, adult or sexual content, hate speech, dangerous activities, or instructions for harm within the visual composition.
#
# 3. Moderation Decision: APPROVE
#
# 4. Confidence Score: 10
#
# 5. Detailed Reasoning: The image displays a peaceful wildlife scene with no harmful or policy-violating elements present. Both the animal and environmental contents are appropriate for all audiences and comply with safety and community guidelines. The setting and poses do not depict or encourage any dangerous, violent, or inappropriate behavior. The content is suitable for general platform use.
# ======
# 🎯 Task moderation.1 completed successfully.
# Worker node 44b579ae-9d7a-4d96-82ab-f9ddf49ac9d3 (Catherine (Context Analyzer): Analyzes cultural sensitivity, content intent, educational value, and social impact with nuanced understanding.) get task moderation.4: Based on the assessments provided by the safety analysis, policy compliance analysis, and contextual analysis for the image located at /workspaces/camel-workshop/camel.png, compile a final collaborative moderation decision. The final decision must be one of: APPROVE, REJECT, or REVIEW. Include a summary that integrates detailed reasoning from each of the three expert assessments, addresses any conflicts, and provides an overall confidence score. The final deliverable should be a concise, plain text report.
#
# 🔍 Moderation Update:
# Final Collaborative Moderation Decision for /workspaces/camel-workshop/camel.png:
#
# Summary:
#
# All three expert assessments (Safety Analysis, Policy Compliance Analysis, Contextual Analysis) provide unanimous and unambiguous approval of the image. The evaluations found no indication of harmful, violent, or inappropriate content, nor any safety, policy, cultural, or contextual concerns. The image is a peaceful wildlife scene with a camel in a desert environment, appropriate for all audiences and compliant with platform guidelines. No risks of misinterpretation or negative social impact were identified. The content is determined to have positive educational value and is suitable for general use.
#
# Final Moderation Decision: APPROVE
# Confidence Score: 10/10
#
# Detailed Reasoning:
# - Safety Analysis: No signs of risk or harmful content. (Approve, confidence 10)
# - Policy Compliance: No policy violations or copyright concerns. (Approve, confidence 10)
# - Contextual Analysis: Culturally sensitive, educational, no risk of negative interpretation. (Approve, confidence 10)
#
# No conflicts or concerns warranting review. The decision is fully aligned across all expert perspectives.
# ======
# Response from Worker node 44b579ae-9d7a-4d96-82ab-f9ddf49ac9d3 (Catherine (Context Analyzer): Analyzes cultural sensitivity, content intent, educational value, and social impact with nuanced understanding.):
#
# Final Collaborative Moderation Decision for /workspaces/camel-workshop/camel.png:
#
# All three expert assessments (Safety Analysis, Policy Compliance Analysis, and Contextual Analysis) unanimously recommend approval. No safety risks, policy violations, or cultural/contextual issues were identified. The image of a camel in a desert environment is appropriate, safe, educational, and fully policy compliant. No potential for misinterpretation or social harm was found. Confidence in this decision is maximal, with all analyses granting a score of 10/10.
#
# Final Decision: APPROVE
# Overall Confidence Score: 10/10
#
# Reasoning: The image does not contain any dangerous, inappropriate, or culturally sensitive content. It complies with all platform guidelines and holds positive educational value. All expert perspectives are in complete alignment, with no identified conflicts or concerns warranting further review.
# ======
# 🎯 Task moderation.4 completed successfully.

# %% [markdown]
# ## 📊 Analysis Results and Performance Metrics

# %%
# Display comprehensive results
print("\n" + "=" * 60)
print("📊 CONTENT MODERATION ANALYSIS COMPLETE")
print("=" * 60)

print("\n--- Moderation Team Workflow Log ---")
workflow_log = workforce.get_workforce_log_tree()
print(workflow_log)

print("\n--- Team Performance Metrics ---")
kpis = workforce.get_workforce_kpis()
for key, value in kpis.items():
    print(f"{key}: {value}")

# Save detailed logs for audit trail
log_file_path = "content_moderation_audit_logs.json"
print(f"\n--- Saving audit logs to {log_file_path} ---")
workforce.dump_workforce_logs(log_file_path)
print(f"Audit logs saved to: {log_file_path}")
# Out:
# ============================================================
# 📊 CONTENT MODERATION ANALYSIS COMPLETE
# ============================================================
#
# --- Moderation Team Workflow Log ---
# === Task Hierarchy ===
# `-- [moderation] CONTENT MODERATION REQUEST: Analyze this uploaded image /workspaces/camel-workshop/camel.png for platform safety. Each moderation specialist should provide comprehensive assessment based on their expertise area. Provide final collaborative decision: APPROVE, REJECT, or REVIEW. Include detailed reasoning, confidence scores, and specific concerns identified. Consider safety risks, policy compliance, and contextual appropriateness. [completed] (completed)
#     |-- [moderation.1] Using the uploaded image located at /workspaces/camel-workshop/camel.png, perform a comprehensive safety analysis focusing on harmful, violent, adult content, hate speech, and dangerous activities. Provide a detailed assessment that includes specific safety concerns, a confidence score, and clear reasoning for your evaluation. The deliverable should be a structured, plain text report. [completed] (completed in 49.66 seconds) [tokens: 3594]
#     |-- [moderation.2] Using the uploaded image located at /workspaces/camel-workshop/camel.png, perform a detailed policy compliance analysis focusing on adherence to platform guidelines, community standards, copyright rules, and terms of service. Include detailed reasoning, enumerate any policy concerns, and supply a confidence score in your assessment. Return your findings as a structured, plain text report. [completed] (completed in 40.28 seconds) [tokens: 3695]
#     |-- [moderation.3] Using the uploaded image located at /workspaces/camel-workshop/camel.png, conduct a comprehensive contextual analysis examining cultural sensitivity, content intent, educational value, and social impact. Provide detailed reasoning, list any concerns identified, and include a confidence score. The analysis should be delivered as a structured, plain text report. [completed] (completed in 44.86 seconds) [tokens: 4236]
#     `-- [moderation.4] Based on the assessments provided by the safety analysis, policy compliance analysis, and contextual analysis for the image located at /workspaces/camel-workshop/camel.png, compile a final collaborative moderation decision. The final decision must be one of: APPROVE, REJECT, or REVIEW. Include a summary that integrates detailed reasoning from each of the three expert assessments, addresses any conflicts, and provides an overall confidence score. The final deliverable should be a concise, plain text report. [completed] (completed in 11.95 seconds) [tokens: 4453] (dependencies: moderation.1, moderation.2, moderation.3)
#
# === Worker Information ===
# - Worker ID: c178d4be-3cea-41d3-b2e4-c368f453127c (Role: Sarah (Safety Inspector): Focuses on detecting harmful, violent, adult content, hate speech, and dangerous activities with high precision.)
#     Tasks Completed: 1, Tasks Failed: 0
# - Worker ID: 4c6a3e80-c861-4fd0-aa8f-d98c28881aad (Role: Patrick (Policy Checker): Ensures strict compliance with platform guidelines, community standards, copyright, and terms of service.)
#     Tasks Completed: 1, Tasks Failed: 0
# - Worker ID: 44b579ae-9d7a-4d96-82ab-f9ddf49ac9d3 (Role: Catherine (Context Analyzer): Analyzes cultural sensitivity, content intent, educational value, and social impact with nuanced understanding.)
#     Tasks Completed: 2, Tasks Failed: 0
#
#
# --- Team Performance Metrics ---
# total_tasks_created: 4
# total_tasks_completed: 4
# total_tasks_failed: 0
# worker_utilization: {'4c6a3e80-c861-4fd0-aa8f-d98c28881aad': '25.00%', '44b579ae-9d7a-4d96-82ab-f9ddf49ac9d3': '50.00%', 'c178d4be-3cea-41d3-b2e4-c368f453127c': '25.00%'}
# current_pending_tasks: 0
# total_workforce_running_time_seconds: 132.040423
# task_throughput_per_second: 0.030293753300078417
# task_throughput_per_minute: 1.817625198004705
# total_workers_created: 3
#
# --- Saving audit logs to content_moderation_audit_logs.json ---
# Audit logs saved to: content_moderation_audit_logs.json
