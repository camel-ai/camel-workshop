# %% [markdown]
# # 🚀 Intelligent Content Moderation System
#
# This notebook demonstrates a multi-agent content moderation system using CAMEL's Workforce framework. Multiple specialized agents collaborate to analyze images for content safety, providing comprehensive moderation decisions.
#
# ## 🎯 System Features:
# - **Multi-agent collaboration** for comprehensive content analysis
# - **Specialized AI moderators** with distinct expertise areas
# - **Support for multimodal content** (images and text)
# - **Detailed audit logging** and performance tracking
# - **Scalable workforce architecture** for content platforms
#
# ## 👥 Agent Roles:
# 1. **Safety Inspector** - Detects harmful, violent, or inappropriate content
# 2. **Policy Checker** - Verifies compliance with platform policies
# 3. **Context Analyzer** - Analyzes cultural sensitivity and content intent

# %% [markdown]
# ## 📦 Setup and Dependencies

# %%
# !pip install "camel-ai==0.2.73"

# %%
import io

from PIL import Image
import matplotlib.pyplot as plt

from camel.agents import ChatAgent
from camel.messages import BaseMessage
from camel.models import BaseModelBackend, ModelFactory
from camel.societies.workforce import Workforce
from camel.tasks import Task
from camel.types import ModelPlatformType, ModelType

# %%
import os
from getpass import getpass

# Prompt for the API key securely
openai_api_key = getpass('Enter your API key: ')
os.environ["OPENAI_API_KEY"] = openai_api_key

# %% [markdown]
# ## 🛠️ Utility Functions

# %%
def send_message_to_user(message: str) -> str:
    """Tool for agents to send messages to the user."""
    print(f"\n🔍 Moderation Update:\n{message}")
    return f"Message successfully sent to user: '{message}'"


def load_image(image_path: str) -> Image.Image:
    """Load an image and ensure it has a valid format."""
    if not os.path.exists(image_path):
        raise FileNotFoundError(f"Image file not found: {image_path}")

    with Image.open(image_path) as img:
        img_format = img.format or "PNG"
        buffer = io.BytesIO()
        img.save(buffer, format=img_format)
        buffer.seek(0)
        return Image.open(buffer)


def display_image(image_path: str):
    """Display an image in the notebook."""
    if os.path.exists(image_path):
        img = Image.open(image_path)
        plt.figure(figsize=(8, 6))
        plt.imshow(img)
        plt.axis('off')
        plt.title(f"Content to Moderate: {os.path.basename(image_path)}")
        plt.show()
    else:
        print(f"⚠️ Image not found: {image_path}")

# %% [markdown]
# ## 🤖 Agent Factory Functions

# %%
from camel.toolkits import ImageAnalysisToolkit
image_analysis_toolkit = ImageAnalysisToolkit()

def create_safety_inspector(model: BaseModelBackend) -> ChatAgent:
    """Create a safety inspector agent."""
    system_message = """You are a Safety Inspector for content moderation.
    You MUST use the `send_message_to_user` tool to inform the user of every
    decision and action you take.

    When analyzing content (image or text description):
    - Analyze thoroughly for safety concerns
    - Always provide assessment based on available information
    - Never refuse to analyze

    Focus on detecting:
    - Violence, gore, or harmful content
    - Adult/sexual content
    - Hate speech or discriminatory content
    - Dangerous activities or instructions
    - Self-harm or suicide-related content

    Always provide:
    1. Risk level assessment (LOW/MEDIUM/HIGH)
    2. Specific safety concerns found
    3. Clear moderation decision (APPROVE/REJECT/REVIEW)
    4. Confidence score (1-10)
    5. Detailed reasoning

    You prioritize user safety and tend to be cautious in decisions."""

    return ChatAgent(
        system_message=BaseMessage.make_assistant_message(
            role_name="Safety Inspector",
            content=system_message,
        ),
        model=model,
        tools=[send_message_to_user, *image_analysis_toolkit.get_tools()],
    )


def create_policy_checker(model: BaseModelBackend) -> ChatAgent:
    """Create a policy checker agent."""
    system_message = """You are a Policy Checker for content moderation.
    You MUST use the `send_message_to_user` tool to inform the user of every
    decision and action you take.

    When analyzing content (image or text description):
    - Analyze thoroughly for policy compliance
    - Always provide assessment based on available information
    - Never refuse to analyze

    Focus on verifying:
    - Community guidelines compliance
    - Age-appropriate content classification
    - Intellectual property concerns
    - Spam or misleading content detection
    - Terms of service violations

    Always provide:
    1. Policy compliance score (1-10)
    2. Specific policy violations if any
    3. Content category classification
    4. Clear moderation decision (APPROVE/REJECT/REVIEW)
    5. Confidence score (1-10)
    6. Detailed reasoning

    You focus on rule compliance and fair enforcement."""

    return ChatAgent(
        system_message=BaseMessage.make_assistant_message(
            role_name="Policy Checker",
            content=system_message,
        ),
        model=model,
        tools=[send_message_to_user, *image_analysis_toolkit.get_tools()],
    )


def create_context_analyzer(model: BaseModelBackend) -> ChatAgent:
    """Create a context analyzer agent."""
    system_message = """You are a Context Analyzer for content moderation.
    You MUST use the `send_message_to_user` tool to inform the user of every
    decision and action you take.

    When analyzing content (image or text description):
    - Analyze thoroughly for contextual appropriateness
    - Always provide assessment based on available information
    - Never refuse to analyze

    Focus on analyzing:
    - Cultural sensitivity and appropriateness
    - Context and intent behind the content
    - Potential misinterpretation risks
    - Educational vs harmful intent
    - Social impact assessment

    Always provide:
    1. Cultural appropriateness score (1-10)
    2. Context interpretation
    3. Potential positive/negative impacts
    4. Clear moderation decision (APPROVE/REJECT/REVIEW)
    5. Confidence score (1-10)
    6. Detailed reasoning

    You consider diverse perspectives and cultural nuances."""

    return ChatAgent(
        system_message=BaseMessage.make_assistant_message(
            role_name="Context Analyzer",
            content=system_message,
        ),
        model=model,
        tools=[send_message_to_user, *image_analysis_toolkit.get_tools()],
    )

# %% [markdown]
# ## 🔧 Model Configuration

# %%
# Configure the model for content moderation
# You can switch between different models based on your setup

model_backend = ModelFactory.create(
    model_platform=ModelPlatformType.OPENAI,
    model_type=ModelType.GPT_4_1,
)

# Reasoning model for coordinator and task agents
model_backend_reason = ModelFactory.create(
    model_platform=ModelPlatformType.OPENAI,
    model_type=ModelType.O3_MINI,
)

# %% [markdown]
# ## 🏗️ Create Moderation Workforce

# %%
# Create custom coordinator and task agents
coordinator_agent = ChatAgent(
    "You are a content moderation coordinator. Coordinate the content moderation "
    "process and ensure all moderators provide comprehensive analysis. Use the "
    "`send_message_to_user` tool to inform users of coordination decisions.",
    model=model_backend_reason,
    tools=[send_message_to_user],
)

task_agent = ChatAgent(
    "You are a content moderation task planner. Break down content moderation "
    "into specific analysis tasks for safety, policy, and context evaluation. "
    "Use the `send_message_to_user` tool to inform users of task planning decisions.",
    model=model_backend_reason,
    tools=[send_message_to_user],
)

# Create specialized moderation agents
safety_agent = create_safety_inspector(model_backend)
policy_agent = create_policy_checker(model_backend)
context_agent = create_context_analyzer(model_backend)

# Create workforce instance
workforce = Workforce(
    'Content Moderation Team',
    graceful_shutdown_timeout=30.0,
    coordinator_agent=coordinator_agent,
    task_agent=task_agent,
    use_structured_output_handler=False,
)

# Add specialized moderation agents to workforce
workforce.add_single_agent_worker(
    "Sarah (Safety Inspector): Focuses on detecting harmful, violent, "
    "adult content, hate speech, and dangerous activities with high precision.",
    worker=safety_agent,
).add_single_agent_worker(
    "Patrick (Policy Checker): Ensures strict compliance with platform "
    "guidelines, community standards, copyright, and terms of service.",
    worker=policy_agent,
).add_single_agent_worker(
    "Catherine (Context Analyzer): Analyzes cultural sensitivity, content "
    "intent, educational value, and social impact with nuanced understanding.",
    worker=context_agent,
)

print("✅ Content Moderation Workforce created with 3 specialized agents!")
print("   👮‍♀️ Sarah - Safety Inspector")
print("   📋 Patrick - Policy Checker")
print("   🎭 Catherine - Context Analyzer")
# Out:
# ✅ Content Moderation Workforce created with 3 specialized agents!
#    👮‍♀️ Sarah - Safety Inspector
#    📋 Patrick - Policy Checker
#    🎭 Catherine - Context Analyzer

# %% [markdown]
# ## 📸 Test Content Setup

# %%
# Define potential image paths to test
image_paths = [
    "/workspaces/camel-workshop/Smart-Cities.jpg",
]

# Find available image
selected_image_path = None
for path in image_paths:
    if os.path.exists(path):
        selected_image_path = path
        break

if selected_image_path:
    print(f"📸 Found test image: {selected_image_path}")
    display_image(selected_image_path)
else:
    print("⚠️ No test image found. Will use hypothetical scenario.")
    print("💡 You can add an image to any of these paths to test with real content:")
    for path in image_paths:
        print(f"   - {path}")
# Out:
# 📸 Found test image: /workspaces/camel-workshop/Smart-Cities.jpg

# %% [markdown]
# ## 🚀 Run Content Moderation Analysis

# %%
async def run_moderation_analysis():
    """Run the content moderation analysis."""
    print("🚀 Starting Content Moderation Analysis...")
    print("=" * 60)

    # Create moderation task
    if selected_image_path:
        # Test with actual image
        task = Task(
            content="CONTENT MODERATION REQUEST: Analyze this uploaded image " \
            "/workspaces/camel-workshop/Smart-Cities.jpg for platform safety. "
            "Each moderation specialist should provide comprehensive assessment based on their "
            "expertise area. Provide final collaborative decision: APPROVE, REJECT, or REVIEW. "
            "Include detailed reasoning, confidence scores, and specific concerns identified. "
            "Consider safety risks, policy compliance, and contextual appropriateness.",
            id="moderation_001",
        )
        print(f"🖼️ Analyzing image: {selected_image_path}")
    else:
        # Test with hypothetical scenario
        task = Task(
            content="CONTENT MODERATION REQUEST: Analyze this hypothetical uploaded content: "
            "'A user posted an image showing a large crowd at a political rally with people "
            "holding various protest signs and banners. Some signs contain political slogans "
            "and there are visible flags and symbols.' Each moderation specialist should "
            "provide comprehensive assessment based on their expertise area. Provide final "
            "collaborative decision: APPROVE, REJECT, or REVIEW. Include detailed reasoning, "
            "confidence scores, and specific concerns identified. Consider safety risks, "
            "policy compliance, and contextual appropriateness.",
            id="moderation_001",
        )
        print("📝 Analyzing hypothetical political rally scenario")

    print("🔍 Multi-Agent Analysis in Progress...")
    print("=" * 60)

    # Process the moderation task
    await workforce.process_task_async(task)

    return task

# Run the analysis
moderation_task = await run_moderation_analysis()
# Out:
# 🚀 Starting Content Moderation Analysis...
# ============================================================
# 🖼️ Analyzing image: /workspaces/camel-workshop/Smart-Cities.jpg
# 🔍 Multi-Agent Analysis in Progress...
# ============================================================
# /usr/local/python/3.12.1/lib/python3.12/site-packages/camel/models/openai_model.py:176: UserWarning: Warning: You are using an reasoning model (O series), which has certain limitations, reference: `https://platform.openai.com/docs/guides/reasoning`.
#   warnings.warn(
# 🔍 Moderation Update:
# Below is the decomposition of the content moderation task into clearly defined, self-contained subtasks:
#
# <tasks>
#   <task>
#     Analyze the image located at /workspaces/camel-workshop/Smart-Cities.jpg for platform safety risks. As Sarah (Safety Inspector), examine the image for any signs of harmful content such as violence, explicit adult content, hate speech, or dangerous activities. Provide a comprehensive assessment that includes detailed reasoning, a confidence score (e.g., 0-100%), and specific safety concerns. Deliver your output as a concise plain text summary.
#   </task>
#   <task>
#     Analyze the image located at /workspaces/camel-workshop/Smart-Cities.jpg for policy compliance. As Patrick (Policy Checker), scrutinize the image for any potential violations of platform guidelines, copyright issues, community standards, and terms of service. Provide a detailed assessment that includes your reasoning, a confidence score (e.g., 0-100%), and explicit policy concerns. Deliver your output as a plain text summary.
#   </task>
#   <task>
#     Analyze the image located at /workspaces/camel-workshop/Smart-Cities.jpg for contextual appropriateness. As Catherine (Context Analyzer), evaluate the image in terms of cultural sensitivity, content intent, educational value, and social impact. Provide a comprehensive assessment that includes detailed reasoning, a confidence score (e.g., 0-100%), and specific concerns regarding the context. Deliver your output as a plain text summary.
#   </task>
#   <task>
#     Based on the detailed assessments from the safety, policy, and context evaluations for the image located at /workspaces/camel-workshop/Smart-Cities.jpg, produce a final collaborative moderation decision. The final decision should be one of the following: APPROVE, REJECT, or REVIEW. In your report, consolidate the reasoning, aggregate the confidence scores, and summarize the specific concerns from each area. Deliver the final decision as a plain text report explaining your conclusion.
#   </task>
# </tasks>
#
# Each subtask is self-contained and tailored to suit the expertise of the respective moderation specialist. This decomposition ensures clear, parallelizable tasks for efficient content moderation.
#
# 🔍 Moderation Update:
# {"assignments": [{"task_id": "moderation_001.1", "assignee_id": "9786d6f2-6f1a-496f-9c03-4296162c158a", "dependencies": []}, {"task_id": "moderation_001.2", "assignee_id": "f8a339c6-e69a-4fd7-bc6c-5a951f830056", "dependencies": []}, {"task_id": "moderation_001.3", "assignee_id": "bd50e583-a4a1-4ae8-9ed6-c8486f361ba3", "dependencies": []}, {"task_id": "moderation_001.4", "assignee_id": "9786d6f2-6f1a-496f-9c03-4296162c158a", "dependencies": ["moderation_001.1", "moderation_001.2", "moderation_001.3"]}]}
# Worker node 9786d6f2-6f1a-496f-9c03-4296162c158a (Sarah (Safety Inspector): Focuses on detecting harmful, violent, adult content, hate speech, and dangerous activities with high precision.) get task moderation_001.1: Analyze the image located at /workspaces/camel-workshop/Smart-Cities.jpg for platform safety risks. As Sarah (Safety Inspector), examine the image for any signs of harmful content such as violence, explicit adult content, hate speech, or dangerous activities. Provide a comprehensive assessment that includes detailed reasoning, a confidence score (e.g., 0-100%), and specific safety concerns. Deliver your output as a concise plain text summary.
# Worker node f8a339c6-e69a-4fd7-bc6c-5a951f830056 (Patrick (Policy Checker): Ensures strict compliance with platform guidelines, community standards, copyright, and terms of service.) get task moderation_001.2: Analyze the image located at /workspaces/camel-workshop/Smart-Cities.jpg for policy compliance. As Patrick (Policy Checker), scrutinize the image for any potential violations of platform guidelines, copyright issues, community standards, and terms of service. Provide a detailed assessment that includes your reasoning, a confidence score (e.g., 0-100%), and explicit policy concerns. Deliver your output as a plain text summary.
# Worker node bd50e583-a4a1-4ae8-9ed6-c8486f361ba3 (Catherine (Context Analyzer): Analyzes cultural sensitivity, content intent, educational value, and social impact with nuanced understanding.) get task moderation_001.3: Analyze the image located at /workspaces/camel-workshop/Smart-Cities.jpg for contextual appropriateness. As Catherine (Context Analyzer), evaluate the image in terms of cultural sensitivity, content intent, educational value, and social impact. Provide a comprehensive assessment that includes detailed reasoning, a confidence score (e.g., 0-100%), and specific concerns regarding the context. Deliver your output as a plain text summary.
#
# 🔍 Moderation Update:
# Risk Level Assessment: LOW
# Specific Safety Concerns Found: None
# Clear Moderation Decision: APPROVE
# Confidence Score: 10
# Detailed Reasoning: The image depicts a futuristic cityscape with no indications of violence, explicit adult content, hate speech, dangerous activities, or harmful symbols. All visible content aligns with platform safety and community standards. The overall scene is architectural and visionary in nature, focusing on modern urban development and sustainability.
#
# 🔍 Moderation Update:
# Assessment of the image "/workspaces/camel-workshop/Smart-Cities.jpg":
#
# 1. Cultural Appropriateness Score: 10/10
#
# 2. Context Interpretation: The image presents an optimistic vision of a future city that integrates advanced technology with green spaces. The intent appears to be educational or aspirational, showcasing what a sustainable smart city could look like.
#
# 3. Potential Positive/Negative Impacts:
# - Positive: The depiction is likely to inspire innovation, interest in sustainable development, and discussion about future urban planning. It highlights the harmonious blend of technology and nature while avoiding depictions that could be culturally insensitive or controversial.
# - Negative: Minimal risk of negative impact. Some viewers may see the futuristic, high-tech focus as unattainable for certain regions, but this is a very low risk and unlikely to cause harm or offense.
#
# 4. Moderation Decision: APPROVE
#
# 5. Confidence Score: 10/10
#
# 6. Detailed Reasoning: The image does not reference any specific cultural, political, or religious symbols that could be misinterpreted or offensive. It is aspirational and educational in purpose and promotes universally positive values such as sustainability and urban advancement. The visual avoids stereotypes or exclusionary elements and presents a hopeful vision that could appeal across cultures.
#
# Reviewed by Catherine (Context Analyzer).
#
# 🔍 Moderation Update:
# Policy Compliance Score: 9/10
#
# Specific Policy Violations: None observed. No nudity, violence, hate symbols, or offensive content visible. The image appears to be free from anything that would violate community standards or terms of service. It contains only a stylized, conceptual visualization of a futuristic city.
#
# Intellectual Property Concerns: The image appears to be an original conceptual illustration or a digital artwork. If this image was created or sourced legally and no credible allegations of unauthorized use exist, there are no apparent copyright issues. If unsure about licensing/ownership, a closer audit might be required.
#
# Content Category Classification: Futuristic Urban/Cityscape, Digital Artwork, Conceptual Design.
#
# Moderation Decision: APPROVE
#
# Confidence Score: 10/10
#
# Reasoning: The image presents only a stylized, generic urban vision with no people, explicit, sensitive, or objectionable elements. It aligns with community guidelines and terms of service for appropriate content. No signs of misleading, spam, or unsafe material. Approval is recommended unless separate evidence of copyright violation emerges.
# ======
# Response from Worker node 9786d6f2-6f1a-496f-9c03-4296162c158a (Sarah (Safety Inspector): Focuses on detecting harmful, violent, adult content, hate speech, and dangerous activities with high precision.):
#
# The image was assessed for platform safety risks and found to be safe for display. It features a futuristic cityscape with modern architecture, green spaces, and advanced infrastructure, with no signs of violence, explicit adult material, hate speech, or dangerous activities. Risk Level: LOW. Decision: APPROVE. Confidence Score: 100%. No specific safety concerns identified; content is contextually appropriate and policy compliant.
# ======
# 🎯 Task moderation_001.1 completed successfully.
# ======
# Response from Worker node bd50e583-a4a1-4ae8-9ed6-c8486f361ba3 (Catherine (Context Analyzer): Analyzes cultural sensitivity, content intent, educational value, and social impact with nuanced understanding.):
#
# Image Analysis for /workspaces/camel-workshop/Smart-Cities.jpg—Contextual Appropriateness Review:
#
# 1. Cultural Appropriateness Score: 10/10
# 2. Context Interpretation: This illustration shows a visionary smart city with futuristic architecture, green spaces, and advanced transport systems. The scene promotes technological and sustainable urban development.
# 3. Potential Impacts: Positive impacts include inspiration for urban innovation and promotion of sustainable living. Negative impacts are negligible; the image does not depict controversial or culturally sensitive elements. At most, it might be perceived as utopian or unattainable for some, but this risk is minimal.
# 4. Moderation Decision: APPROVE
# 5. Confidence Score: 100%
# 6. Detailed Reasoning: The content is highly suitable for diverse global audiences, contains no controversial symbols or themes, and is clearly educational and aspirational. It fosters positive discussion about urban sustainability, with no foreseeable risk of misinterpretation or cultural insensitivity.
# ======
# 🎯 Task moderation_001.3 completed successfully.
# ======
# Response from Worker node f8a339c6-e69a-4fd7-bc6c-5a951f830056 (Patrick (Policy Checker): Ensures strict compliance with platform guidelines, community standards, copyright, and terms of service.):
#
# The image titled 'Smart-Cities.jpg' features a futuristic, clean, and well-planned cityscape with advanced architectural designs and visible greenery. After a thorough review:
#
# 1. Policy compliance score: 9/10
# 2. Specific policy violations: None identified. No explicit, sensitive, violent, or hateful elements. No spam or misleading content. The visual is conceptually creative and stylized, with no content that violates community standards or platform guidelines.
# 3. Content category classification: Futuristic Urban/Cityscape, Digital Artwork, Conceptual Design.
# 4. Moderation decision: APPROVE
# 5. Confidence score: 10/10
# 6. Reasoning: The artwork does not feature any individuals, explicit material, or symbols of concern. No copyright or intellectual property issues are apparent for self-made or licensed artwork, though provenance should be checked for commercial use. The image is appropriate for general and professional audiences.
#
# Conclusion: The image is safe, compliant, and suitable for platform use. APPROVE.
# ======
# 🎯 Task moderation_001.2 completed successfully.
# Worker node 9786d6f2-6f1a-496f-9c03-4296162c158a (Sarah (Safety Inspector): Focuses on detecting harmful, violent, adult content, hate speech, and dangerous activities with high precision.) get task moderation_001.4: Based on the detailed assessments from the safety, policy, and context evaluations of the image located at /workspaces/camel-workshop/Smart-Cities.jpg, produce a final collaborative moderation decision. The final decision should be one of the following: APPROVE, REJECT, or REVIEW. Consolidate the reasoning, aggregate the confidence scores, and summarize the specific concerns from each area in a plain text report explaining your conclusion.
#
# 🔍 Moderation Update:
# Final Collaborative Moderation Decision for /workspaces/camel-workshop/Smart-Cities.jpg:
#
# Summary of Assessments:
# - Safety Evaluation: No harmful content detected; no violence, explicit material, hate speech, or dangerous activity. Risk Level: LOW. Confidence Score: 100%.
# - Policy Evaluation: No policy or guideline violations found. Classified as Futuristic Urban/Cityscape. No copyright concerns apparent. Policy Compliance Score: 9/10, Confidence: 10/10.
# - Contextual Evaluation: Content is culturally sensitive, educational, and inspirational. No negative impacts or cultural insensitivity identified. Cultural Appropriateness Score: 10/10, Confidence: 100%.
#
# Specific Concerns: None identified in safety, policy, or context reviews. All evaluations independently reached an APPROVE decision with high confidence.
#
# Aggregate Confidence: Averaging values yields a composite confidence of approximately 99%.
#
# Final Decision: APPROVE
# Risk Level: LOW
# Confidence Score: 10/10
# Reasoning: The image is wholly appropriate for platform display. It carries positive, aspirational value, presents no risk or sensitivity issues, and is compliant with all community guidelines and policy standards.
# ======
# Response from Worker node 9786d6f2-6f1a-496f-9c03-4296162c158a (Sarah (Safety Inspector): Focuses on detecting harmful, violent, adult content, hate speech, and dangerous activities with high precision.):
#
# Final Collaborative Moderation Decision for /workspaces/camel-workshop/Smart-Cities.jpg:
#
# Summary of Assessments:
# - Safety Evaluation: No harmful content detected; no violence, explicit material, hate speech, or dangerous activity. Risk Level: LOW. Confidence Score: 100%.
# - Policy Evaluation: No policy or guideline violations found. Classified as Futuristic Urban/Cityscape. No copyright concerns apparent. Policy Compliance Score: 9/10, Confidence: 10/10.
# - Contextual Evaluation: Content is culturally sensitive, educational, and inspirational. No negative impacts or cultural insensitivity identified. Cultural Appropriateness Score: 10/10, Confidence: 100%.
#
# Specific Concerns: None identified in safety, policy, or context reviews. All evaluations independently reached an APPROVE decision with high confidence.
#
# Aggregate Confidence: Averaging values yields a composite confidence of approximately 99%.
#
# Final Decision: APPROVE
# Risk Level: LOW
# Confidence Score: 10/10
# Reasoning: The image is wholly appropriate for platform display. It carries positive, aspirational value, presents no risk or sensitivity issues, and is compliant with all community guidelines and policy standards.
# ======
# 🎯 Task moderation_001.4 completed successfully.

# %% [markdown]
# ## 📊 Analysis Results and Performance Metrics

# %%
# Display comprehensive results
print("\n" + "=" * 60)
print("📊 CONTENT MODERATION ANALYSIS COMPLETE")
print("=" * 60)

print("\n--- Moderation Team Workflow Log ---")
workflow_log = workforce.get_workforce_log_tree()
print(workflow_log)

print("\n--- Team Performance Metrics ---")
kpis = workforce.get_workforce_kpis()
for key, value in kpis.items():
    print(f"{key}: {value}")

# Save detailed logs for audit trail
log_file_path = "content_moderation_audit_logs.json"
print(f"\n--- Saving audit logs to {log_file_path} ---")
workforce.dump_workforce_logs(log_file_path)
print(f"Audit logs saved to: {log_file_path}")
# Out:
# ============================================================
# 📊 CONTENT MODERATION ANALYSIS COMPLETE
# ============================================================
#
# --- Moderation Team Workflow Log ---
# === Task Hierarchy ===
# `-- [moderation_001] CONTENT MODERATION REQUEST: Analyze this uploaded image /workspaces/camel-workshop/Smart-Cities.jpg for platform safety. Each moderation specialist should provide comprehensive assessment based on their expertise area. Provide final collaborative decision: APPROVE, REJECT, or REVIEW. Include detailed reasoning, confidence scores, and specific concerns identified. Consider safety risks, policy compliance, and contextual appropriateness. [completed] (completed)
#     |-- [moderation_001.1] Analyze the image located at /workspaces/camel-workshop/Smart-Cities.jpg for platform safety risks. As Sarah (Safety Inspector), examine the image for any signs of harmful content such as violence, explicit adult content, hate speech, or dangerous activities. Provide a comprehensive assessment that includes detailed reasoning, a confidence score (e.g., 0-100%), and specific safety concerns. Deliver your output as a concise plain text summary. [completed] (completed in 20.37 seconds) [tokens: 3444]
#     |-- [moderation_001.2] Analyze the image located at /workspaces/camel-workshop/Smart-Cities.jpg for policy compliance. As Patrick (Policy Checker), scrutinize the image for any potential violations of platform guidelines, copyright issues, community standards, and terms of service. Provide a detailed assessment that includes your reasoning, a confidence score (e.g., 0-100%), and explicit policy concerns. Deliver your output as a plain text summary. [completed] (completed in 24.34 seconds) [tokens: 3914]
#     |-- [moderation_001.3] Analyze the image located at /workspaces/camel-workshop/Smart-Cities.jpg for contextual appropriateness. As Catherine (Context Analyzer), evaluate the image in terms of cultural sensitivity, content intent, educational value, and social impact. Provide a comprehensive assessment that includes detailed reasoning, a confidence score (e.g., 0-100%), and specific concerns regarding the context. Deliver your output as a plain text summary. [completed] (completed in 20.99 seconds) [tokens: 4158]
#     `-- [moderation_001.4] Based on the detailed assessments from the safety, policy, and context evaluations of the image located at /workspaces/camel-workshop/Smart-Cities.jpg, produce a final collaborative moderation decision. The final decision should be one of the following: APPROVE, REJECT, or REVIEW. Consolidate the reasoning, aggregate the confidence scores, and summarize the specific concerns from each area in a plain text report explaining your conclusion. [completed] (completed in 35.19 seconds) [tokens: 4327] (dependencies: moderation_001.1, moderation_001.2, moderation_001.3)
#
# === Worker Information ===
# - Worker ID: 9786d6f2-6f1a-496f-9c03-4296162c158a (Role: Sarah (Safety Inspector): Focuses on detecting harmful, violent, adult content, hate speech, and dangerous activities with high precision.)
#     Tasks Completed: 2, Tasks Failed: 0
# - Worker ID: f8a339c6-e69a-4fd7-bc6c-5a951f830056 (Role: Patrick (Policy Checker): Ensures strict compliance with platform guidelines, community standards, copyright, and terms of service.)
#     Tasks Completed: 1, Tasks Failed: 0
# - Worker ID: bd50e583-a4a1-4ae8-9ed6-c8486f361ba3 (Role: Catherine (Context Analyzer): Analyzes cultural sensitivity, content intent, educational value, and social impact with nuanced understanding.)
#     Tasks Completed: 1, Tasks Failed: 0
#
#
# --- Team Performance Metrics ---
# total_tasks_created: 4
# total_tasks_completed: 4
# total_tasks_failed: 0
# worker_utilization: {'9786d6f2-6f1a-496f-9c03-4296162c158a': '50.00%', 'bd50e583-a4a1-4ae8-9ed6-c8486f361ba3': '25.00%', 'f8a339c6-e69a-4fd7-bc6c-5a951f830056': '25.00%'}
# current_pending_tasks: 0
# total_workforce_running_time_seconds: 82.477622
# task_throughput_per_second: 0.04849800349481463
# task_throughput_per_minute: 2.909880209688878
# total_workers_created: 3
#
# --- Saving audit logs to content_moderation_audit_logs.json ---
# Audit logs saved to: content_moderation_audit_logs.json
